# %% [markdown]
# # Exploratory Data Analysis (EDA) for dataset  `Act_Disaggregated`

# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import json
import requests
#import geopandas as gpd
# %matplotlib inline

# %% [markdown]
# # Data Cleaning & Feature Engineering
# 1. Visualizing a preview of the data of each table to get an idea of the information they contain.

# %%
act_disag = pd.read_excel(f'../Data/ACT_DESAGREGADO.xlsx')
df_cp = act_disag.copy()
df_cp
# Out:
#       NUMERO IDENTIFICACION               NOMBRE ENCUESTA\n  \
# 0                    535255  Prueba de control del Asma ACT
# 1                    535255  Prueba de control del Asma ACT
# 2                    535255  Prueba de control del Asma ACT
# 3                    535255  Prueba de control del Asma ACT
# 4                    535255  Prueba de control del Asma ACT
# ...                     ...                             ...
# 8597                 744564  Prueba de control del Asma ACT
# 8598                 744564  Prueba de control del Asma ACT
# 8599                 744564  Prueba de control del Asma ACT
# 8600                 744564  Prueba de control del Asma ACT
# 8601                 744564  Prueba de control del Asma ACT
#
#                                              PREGUNTA\n  \
# 0     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 1     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 2     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 3     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 4     ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANT...
# ...                                                 ...
# 8597  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 8598  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 8599  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 8600  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...
# 8601  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANT...
#
#                            RESPUESTA FE_RESULTADO
# 0                        POCAS VECES   2012-06-29
# 1            1 O 2 VECES A LA SEMANA   2012-06-29
# 2     DE 2 A 3 NOCHES EN A LA SEMANA   2012-06-29
# 3          1 VEZ A LA SEMANA O MENOS   2012-06-29
# 4                    BIEN CONTROLADA   2012-06-29
# ...                              ...          ...
# 8597                     POCAS VECES   2020-05-20
# 8598         1 O 2 VECES A LA SEMANA   2020-05-20
# 8599                           NUNCA   2020-05-20
# 8600       1 VEZ A LA SEMANA O MENOS   2020-05-20
# 8601                 BIEN CONTROLADA   2020-05-20
#
# [8602 rows x 5 columns]

# %% [markdown]
# ### Analyse null data

# %%
msno.matrix(msno.nullity_sort(df_cp, sort='descending'))

# %% [markdown]
# ## Data description:
# The ATC_DESAGREGADOS dataset together with the ACT collects information from the Asthma Control test. We have the patients ID, the name of the test taken and the questions as well as the scoring taken. These two datasets differ in that the ATC_DESAGREGADOS has the questions and answers of the test as such. While the ACT has the consolidated table (contains the scoring).
#
# ### Conclusion:
#
# We have 8602 patient records with 5 characteristics or columns

# %%
act_df = df_cp.groupby(['NUMERO IDENTIFICACION']).count()
#act_disag.columns
print(df_cp.info())
#print(act_disag.info)
print(act_df)
df_cp.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8602 entries, 0 to 8601
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NUMERO IDENTIFICACION  8602 non-null   int64
#  1   NOMBRE ENCUESTA
#        8602 non-null   object
#  2   PREGUNTA
#               8602 non-null   object
#  3   RESPUESTA              8602 non-null   object
#  4   FE_RESULTADO           8602 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 336.1+ KB
# None
#                        NOMBRE ENCUESTA\n  PREGUNTA\n  RESPUESTA  FE_RESULTADO
# NUMERO IDENTIFICACION
# 502989                                25          25         25            25
# 506808                                10          10         10            10
# 512938                                40          40         40            40
# 514102                                 5           5          5             5
# 524006                                60          60         60            60
# ...                                  ...         ...        ...           ...
# 1995390                               10          10         10            10
# 1995612                               45          45         45            45
# 1997065                               20          20         20            20
# 1998401                               30          30         30            30
# 1999629                               10          10         10            10
#
# [456 rows x 4 columns]
#         NUMERO IDENTIFICACION               NOMBRE ENCUESTA\n  \
# count            8.602000e+03                            8602
# unique                    NaN                               1
# top                       NaN  Prueba de control del Asma ACT
# freq                      NaN                            8602
# first                     NaN                             NaN
# last                      NaN                             NaN
# mean             1.254126e+06                             NaN
# std              4.153052e+05                             NaN
# min              5.029890e+05                             NaN
# 25%              9.036320e+05                             NaN
# 50%              1.251351e+06                             NaN
# 75%              1.617372e+06                             NaN
# max              1.999629e+06                             NaN
#
#                                                PREGUNTA\n RESPUESTA  \
# count                                                8602      8602
# unique                                                 32        31
# top     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUEN...     NUNCA
# freq                                                 1715      2676
# first                                                 NaN       NaN
# last                                                  NaN       NaN
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                FE_RESULTADO
# count                  8602
# unique                  526
# top     2018-09-20 00:00:00
# freq                    325
# first   2012-06-29 00:00:00
# last    2020-05-29 00:00:00
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# 2. Now we will set a standard format for naming the fields: lowercase and underscore instead of spaces. For this, we will start first with the column `PREGUNTAS` and `RESPUESTA`, since there is a bunch of data mixed all together in this section

# %%
df_cp.columns = [col.lower() for col in  df_cp.columns]
df_cp.rename(columns={
    'numero identificacion':'id_paciente',
    'nombre encuesta\n':'nombre_encuesta',
    'respuesta' : 'respuesta',
    'fe_resultado': 'fe_resultado'
}, inplace = True)
df_cp.groupby('id_paciente').count()
# Out:
#              nombre_encuesta  pregunta\n  respuesta  fe_resultado
# id_paciente
# 502989                    25          25         25            25
# 506808                    10          10         10            10
# 512938                    40          40         40            40
# 514102                     5           5          5             5
# 524006                    60          60         60            60
# ...                      ...         ...        ...           ...
# 1995390                   10          10         10            10
# 1995612                   45          45         45            45
# 1997065                   20          20         20            20
# 1998401                   30          30         30            30
# 1999629                   10          10         10            10
#
# [456 rows x 4 columns]

# %%
df_cp.columns
# Out:
# Index(['id_paciente', 'nombre_encuesta', 'pregunta\n', 'respuesta',
#        'fe_resultado'],
#       dtype='object')

# %%
df_cp.rename(columns = {'pregunta\n':'pregunta'}, inplace = True) 
df_cp.columns
# Out:
# Index(['id_paciente', 'nombre_encuesta', 'pregunta', 'respuesta',
#        'fe_resultado'],
#       dtype='object')

# %% [markdown]
# Thus, column names have been fixed to a standard format that can be matched with the resting datasets

# %% [markdown]
# ### Definition: ACT
#
# The ACT is a validated tool that consists of five questions that you can ask online and offline. It will provide you with an instant reminder of how well you have controlled your asthma over the past four weeks.
#
# The results can help show how much control you really have over your asthma, which may surprise you. It is advisable to perform the test regularly, as asthma symptoms can vary from month to month and depending on the time of year.
#
# You may find it helpful to discuss your ACT score with your doctor or nurse the next time you see them. This can help guide your conversation with them and ensure that you get the most out of your visit.
#
# ### What questions are there in an ACT test
#
# <img src=https://4.bp.blogspot.com/-Dk-c_xGGdPE/Wu7gFY7jeiI/AAAAAAAAJMQ/n00Z5IPMvEAvol1PUfkQfY-CQQcR3fMggCLcBGAs/s1600/Control-si%25CC%2581ntomas-asma-gina.png width="900">
#
#
# ### Column section called `PREGUNTAS` - in dataset  `ACT_Disaggregated`:
# The following 4 questions have 1715 records, which means that 1715 patients carried out this survey and therefore we will have 1715 answers.
#
# A. DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
#
# B. DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
#
# C. DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
#
# D. DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
#
# E. ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
#
# The question `E` is not part of the ACT test,but it is refered as the feedback question regarding the treatment. Therefore it will be considered within our anaylisis
#
# 1. CUANTO TIEMPO LLEVA DE TRATAMIENTO PARA SU PATOLOGIA PRINCIPAL?
# 2. ¿COMO PUNTUARIA SU CALIDAD DE VIDA?
# 3. ¿CON QUE FRECUENCIA TIENE SENTIMIENTOS NEGATIVOS, TALES COMO TRISTEZA, DESESPERANZA,    ANSIEDAD, DEPRESION?
# 4. ¿CUAL ES SU CAPACIDAD DE CONCENTRACION?
# 5. ¿CUAN SALUDABLE ES EL AMBIENTE FISICO DE SU ALREDEDOR?
# 6. ¿CUAN SATISFECHO ESTA CON EL ACCESO QUE TIENE A LOS SERVICIOS SANITARIOS?
# 7. ¿CUAN SATISFECHO ESTA CON EL APOYO QUE TIENE DE SUS AMIGOS?
# 8. ¿CUAN SATISFECHO ESTA CON SU CAPACIDAD DE TRABAJO?
# 9. ¿CUAN SATISFECHO ESTA CON SU HABILIDAD PARA REALIZAR SUS ACTIVIDADES DE LA VIDA DIARIA?
# 10. ¿CUAN SATISFECHO ESTA CON SU SUEÑO?
# 11. ¿CUAN SATISFECHO ESTA CON SU TRANSPORTE?
# 12. ¿CUAN SATISFECHO ESTA CON SU VIDA SEXUAL?
# 13. ¿CUAN SATISFECHO ESTA CON SUS RELACIONES PERSONALES?
# 14. ¿CUAN SATISFECHO ESTA DE LAS CONDICIONES DEL LUGAR DONDE VIVE?
# 15. ¿CUAN SATISFECHO ESTA DE SI MISMO?
# 16. ¿CUAN SATISFECHO/A ESTA CON SU SALUD?
# 17. ¿CUANTA SEGURIDAD SIENTE EN SU VIDA DIARIA?
# 18. ¿CUANTO DISFRUTA DE LA VIDA?
# 19. ¿CUANTO NECESITA DE CUALQUIER TRATAMIENTO MEDICO PARA FUNCIONAR EN SU VIDA DIARIA?
# 20. ¿EN QUE MEDIDA PIENSA QUE EL DOLOR (FISICO) LE IMPIDE HACER LO QUE NECESITA?
# 21. ¿EN QUE MEDIDA SIENTE QUE SU VIDA TIENE SENTIDO?
# 22. ¿ES CAPAZ DE ACEPTAR SU APARIENCIA FISICA?
# 23. ¿ES CAPAZ DE DESPLAZARSE DE UN LUGAR A OTRO?
# 24. ¿HASTA QUE PUNTO TIENE OPORTUNIDAD PARA REALIZAR ACTIVIDADES DE OCIO?
# 25. ¿QUE DISPONIBLE TIENE LA INFORMACION QUE NECESITA EN SU VIDA DIARIA?
# 26. ¿TIENE ENERGIA SUFICIENTE PARA LA VIDA DIARIA?
# 27. ¿TIENE SUFICIENTE DINERO PARA CUBRIR SUS NECESIDADES?

# %% [markdown]
# Convert questions to lowercase format

# %%
pd.set_option('display.max_colwidth', -1)
#df_cp_lower = df_cp['pregunta'].str.lower()
#df_cp['pregunta'] = df_cp_lower
df_cp
# Out:
#       id_paciente                 nombre_encuesta  \
# 0     535255       Prueba de control del Asma ACT
# 1     535255       Prueba de control del Asma ACT
# 2     535255       Prueba de control del Asma ACT
# 3     535255       Prueba de control del Asma ACT
# 4     535255       Prueba de control del Asma ACT
# ...      ...                                  ...
# 8597  744564       Prueba de control del Asma ACT
# 8598  744564       Prueba de control del Asma ACT
# 8599  744564       Prueba de control del Asma ACT
# 8600  744564       Prueba de control del Asma ACT
# 8601  744564       Prueba de control del Asma ACT
#
#                                                                                                                                                                                                                                       pregunta  \
# 0     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 1     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 2     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 3     DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 4     ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# ...                                                                      ...
# 8597  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 8598  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 8599  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 8600  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 8601  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
#
#                            respuesta fe_resultado
# 0     POCAS VECES                    2012-06-29
# 1     1 O 2 VECES A LA SEMANA        2012-06-29
# 2     DE 2 A 3 NOCHES EN A LA SEMANA 2012-06-29
# 3     1 VEZ A LA SEMANA O MENOS      2012-06-29
# 4     BIEN CONTROLADA                2012-06-29
# ...               ...                       ...
# 8597  POCAS VECES                    2020-05-20
# 8598  1 O 2 VECES A LA SEMANA        2020-05-20
# 8599  NUNCA                          2020-05-20
# 8600  1 VEZ A LA SEMANA O MENOS      2020-05-20
# 8601  BIEN CONTROLADA                2020-05-20
#
# [8602 rows x 5 columns]

# %%
#Save data of our interest
df_seg = df_cp.groupby(['respuesta','pregunta'], as_index=False).count()
df1_preg =  df_seg.iloc[:,0:2]
#Work with copy
df1_preg
#df_copy_2 =act_disag['PREGUNTA\n'].map(lambda x: x.lstrip("CON QUE FRECUENCIA LOS SINTOMAS DE ASMA"))
# Out:
#                          respuesta  \
# 0   1 O 2 VECES A LA SEMANA
# 1   1 O 2 VECES AL DIA
# 2   1 VEZ A LA SEMANA O MENOS
# 3   2 O 3 VECES A LA SEMANA
# 4   ALGO CONTROLADA
# 5   ALGUNAS VECES
# 6   BASTANTE
# 7   BASTANTE
# 8   BASTANTE
# 9   BASTANTE
# 10  BASTANTE
# 11  BASTANTE
# 12  BASTANTE
# 13  BASTANTE
# 14  BASTANTE SATISFECHO
# 15  BASTANTE SATISFECHO
# 16  BIEN CONTROLADA
# 17  CASI SIEMPRE
# 18  DE 2 A 3 NOCHES EN A LA SEMANA
# 19  DE 3 A 6 VECES A LA SEMANA
# 20  ENTRE 13 MESES Y 2 AÑOS
# 21  INSATISFECHO
# 22  INSATISFECHO
# 23  INSATISFECHO
# 24  LO NORMAL
# 25  LO NORMAL
# 26  LO NORMAL
# 27  LO NORMAL
# 28  LO NORMAL
# 29  LO NORMAL
# 30  LO NORMAL
# 31  LO NORMAL
# 32  LO NORMAL
# 33  MAL CONTROLADA
# 34  MAS DE 3 VECES AL DIA
# 35  MAS DE 4 NOCHES A LA SEMANA
# 36  MAS DE UNA VEZ AL DIA
# 37  MODERADO
# 38  NADA
# 39  NADA CONTROLADA
# 40  NUNCA
# 41  NUNCA
# 42  NUNCA
# 43  NUNCA
# 44  POCAS VECES
# 45  RARAMENTE
# 46  SIEMPRE
# 47  TOTALMENTE CONTROLADA
# 48  UN POCO
# 49  UNA O DOS VECES
# 50  UNA VEZ A LA SEMANA
# 51  UNA VEZ AL DIA
#
#                                                                                                                                                                                                                                     pregunta
# 0   DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 1   DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 2   DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 3   DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 4   ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# 5   DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 6   ¿CUAL ES SU CAPACIDAD DE CONCENTRACION?
# 7   ¿CUAN SALUDABLE ES EL AMBIENTE FISICO DE SU ALREDEDOR?
# 8   ¿CUANTO DISFRUTA DE LA VIDA?
# 9   ¿EN QUE MEDIDA SIENTE QUE SU VIDA TIENE SENTIDO?
# 10  ¿ES CAPAZ DE DESPLAZARSE DE UN LUGAR A OTRO?
# 11  ¿HASTA QUE PUNTO TIENE OPORTUNIDAD PARA REALIZAR ACTIVIDADES DE OCIO?
# 12  ¿QUE DISPONIBLE TIENE LA INFORMACION QUE NECESITA EN SU VIDA DIARIA?
# 13  ¿TIENE ENERGIA SUFICIENTE PARA LA VIDA DIARIA?
# 14  ¿CUAN SATISFECHO ESTA CON EL ACCESO QUE TIENE A LOS SERVICIOS SANITARIOS?
# 15  ¿CUAN SATISFECHO ESTA DE LAS CONDICIONES DEL LUGAR DONDE VIVE?
# 16  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# 17  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 18  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 19  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 20  CUANTO TIEMPO LLEVA DE TRATAMIENTO PARA SU PATOLOGIA PRINCIPAL?
# 21  ¿CUAN SATISFECHO ESTA CON SU TRANSPORTE?
# 22  ¿CUAN SATISFECHO ESTA CON SU VIDA SEXUAL?
# 23  ¿CUAN SATISFECHO ESTA CON SUS RELACIONES PERSONALES?
# 24  ¿COMO PUNTUARIA SU CALIDAD DE VIDA?
# 25  ¿CUAN SATISFECHO ESTA CON EL APOYO QUE TIENE DE SUS AMIGOS?
# 26  ¿CUAN SATISFECHO ESTA CON SU CAPACIDAD DE TRABAJO?
# 27  ¿CUAN SATISFECHO ESTA CON SU HABILIDAD PARA REALIZAR SUS ACTIVIDADES DE LA VIDA DIARIA?
# 28  ¿CUAN SATISFECHO ESTA CON SU SUEÑO?
# 29  ¿CUAN SATISFECHO ESTA DE SI MISMO?
# 30  ¿CUAN SATISFECHO/A ESTA CON SU SALUD?
# 31  ¿CUANTA SEGURIDAD SIENTE EN SU VIDA DIARIA?
# 32  ¿CUANTO NECESITA DE CUALQUIER TRATAMIENTO MEDICO PARA FUNCIONAR EN SU VIDA DIARIA?
# 33  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# 34  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 35  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 36  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 37  ¿TIENE SUFICIENTE DINERO PARA CUBRIR SUS NECESIDADES?
# 38  ¿EN QUE MEDIDA PIENSA QUE EL DOLOR (FISICO) LE IMPIDE HACER LO QUE NECESITA?
# 39  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# 40  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 41  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?
# 42  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 43  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)
# 44  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 45  ¿CON QUE FRECUENCIA TIENE SENTIMIENTOS NEGATIVOS, TALES COMO TRISTEZA, DESESPERANZA, ANSIEDAD, DEPRESION?
# 46  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?
# 47  ¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?
# 48  ¿ES CAPAZ DE ACEPTAR SU APARIENCIA FISICA?
# 49  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 50  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?
# 51  DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?

# %% [markdown]
# Simplify questions to ACT items and feedback questions.

# %%
#A  = act_disag[act_disag['PREGUNTA\n'].str.contains("CON QUE FRECUENCIA LOS SINTOMAS DE ASMA")].count()
#act_disag.groupby('PREGUNTA\n').count()
df_cp['pregunta'].replace("DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA LOS SINTOMAS DE ASMA (SILBIDOS EN EL PECHO, TOS, FALTA DE AIRE, OPRESION O DOLOR EN EL PECHO) LO/LA HICIERON DESPERTAR DURANTE LA NOCHE O MAS TEMPRANO QUE DE COSTUMBRE POR LA MAÑANA?","A_ACT",inplace=True)
df_cp['pregunta'].replace("DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SINTIO FALTA DE AIRE?","B_ACT",inplace=True)
df_cp['pregunta'].replace("DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA SU ASMA LE IMPIDIO LLEVAR A CABO SUS TAREAS HABITUALES EN EL TRABAJO, EL ESTUDIO O EL HOGAR?","C_ACT",inplace=True)
df_cp['pregunta'].replace("DURANTE LAS ULTIMAS 4 SEMANAS ¿CON QUE FRECUENCIA USO SU INHALADOR DE EFECTO INMEDIATO O SE HIZO NEBULIZACIONES (POR EJEMPLO, SALBUTAMOL?)","D_ACT",inplace=True)

# %% [markdown]
# We will add the Feedback question refered as  `How did you qualify the test`, since this is refered as a feedback response that might be useful for our analysis.

# %%
df_cp['pregunta'].replace("¿COMO CALIFICARIA EL CONTROL DE SU ASMA DURANTE LAS ULTIMAS 4 SEMANAS?","FEEDBACK",inplace=True)
df_cp
# Out:
#       id_paciente                 nombre_encuesta  pregunta  \
# 0     535255       Prueba de control del Asma ACT  C_ACT
# 1     535255       Prueba de control del Asma ACT  B_ACT
# 2     535255       Prueba de control del Asma ACT  A_ACT
# 3     535255       Prueba de control del Asma ACT  D_ACT
# 4     535255       Prueba de control del Asma ACT  FEEDBACK
# ...      ...                                  ...       ...
# 8597  744564       Prueba de control del Asma ACT  C_ACT
# 8598  744564       Prueba de control del Asma ACT  B_ACT
# 8599  744564       Prueba de control del Asma ACT  A_ACT
# 8600  744564       Prueba de control del Asma ACT  D_ACT
# 8601  744564       Prueba de control del Asma ACT  FEEDBACK
#
#                            respuesta fe_resultado
# 0     POCAS VECES                    2012-06-29
# 1     1 O 2 VECES A LA SEMANA        2012-06-29
# 2     DE 2 A 3 NOCHES EN A LA SEMANA 2012-06-29
# 3     1 VEZ A LA SEMANA O MENOS      2012-06-29
# 4     BIEN CONTROLADA                2012-06-29
# ...               ...                       ...
# 8597  POCAS VECES                    2020-05-20
# 8598  1 O 2 VECES A LA SEMANA        2020-05-20
# 8599  NUNCA                          2020-05-20
# 8600  1 VEZ A LA SEMANA O MENOS      2020-05-20
# 8601  BIEN CONTROLADA                2020-05-20
#
# [8602 rows x 5 columns]

# %%
#df1 = df1[['RESPUESTA', 'NUMERO IDENTIFICACION', 'NOMBRE ENCUESTA\n', 'FE_RESULTADO', 'PREGUNTA']]
A_ACT = df_cp[df_cp['pregunta']=='A_ACT']
B_ACT = df_cp[df_cp['pregunta']=='B_ACT']
C_ACT = df_cp[df_cp['pregunta']=='C_ACT']
D_ACT = df_cp[df_cp['pregunta']=='D_ACT']
A_ACT['pregunta']
# Out:
# 2       A_ACT
# 7       A_ACT
# 12      A_ACT
# 17      A_ACT
# 22      A_ACT
#         ...
# 8579    A_ACT
# 8584    A_ACT
# 8589    A_ACT
# 8594    A_ACT
# 8599    A_ACT
# Name: pregunta, Length: 1715, dtype: object

# %% [markdown]
# Delete useless raws.

# %%
A_ACT_Rows = df_cp[df_cp['pregunta'].str.contains('A_ACT')]
B_ACT_Rows = df_cp[df_cp['pregunta'].str.contains('B_ACT')]
C_ACT_Rows = df_cp[df_cp['pregunta'].str.contains('C_ACT')]
D_ACT_Rows = df_cp[df_cp['pregunta'].str.contains('D_ACT')]
FB_ACT_Rows = df_cp[df_cp['pregunta'].str.contains('FEEDBACK')]
frames = [A_ACT_Rows, B_ACT_Rows, C_ACT_Rows, D_ACT_Rows, FB_ACT_Rows]

result = pd.concat(frames)
N_patients = result.groupby('id_paciente').count().shape
print("The number if patients is {0}".format(N_patients))
result.groupby(['id_paciente','fe_resultado']).count()
# Out:
# The number if patients is (456, 4)
#                           nombre_encuesta  pregunta  respuesta
# id_paciente fe_resultado
# 502989      2014-10-28    5                5         5
#             2017-01-03    5                5         5
#             2018-09-25    10               10        10
#             2020-04-24    5                5         5
# 506808      2015-12-05    5                5         5
# ...                      ..               ..        ..
# 1998401     2016-10-11    5                5         5
#             2018-09-19    5                5         5
#             2020-04-22    5                5         5
# 1999629     2018-05-04    5                5         5
#             2018-09-25    5                5         5
#
# [1693 rows x 3 columns]

# %% [markdown]
# Previously we had 8602 and now we have 8575 records, i.e, we have neglected the 27 additional questions due to its lack of relevance and low significance in our population
#
# #### The previous result also tell us that we have actually 456 patients in this record, therefore we have a mean of 18 records per patients. It can be seen as well that: each patient took between 5 and 10 tests on 5 different dates.

# %%
#df_final = result.pivot(index = "id_paciente", columns="pregunta", values="fe_resultado")
N = result.count()
duplicate_ids = result[result.duplicated('id_paciente')]['id_paciente']

# %% [markdown]
# ## 'ANSWER' column
# The possible answers are presented below. The objective would be to try to identify which questions identify the 4 ACT questions and which would be those of the other category

# %%
#df_final = pd.pivot_table(result, index = ["id_paciente"], columns = "pregunta", values = "respuesta",aggfunc='first')

df_final = pd.pivot_table(result, index = [result.index.values,"id_paciente","nombre_encuesta","fe_resultado"], columns = "pregunta", values = "respuesta",aggfunc='first').reset_index(['id_paciente','nombre_encuesta','fe_resultado'])
df_final = pd.pivot_table(result, index = [result.index.values,"id_paciente","nombre_encuesta","fe_resultado"], columns = "pregunta", values = "respuesta",aggfunc='first').reset_index(['id_paciente','nombre_encuesta','fe_resultado'])

#plt.figure(figsize=(7,4))
#df_final['B_ACT'].hist(bins=20)
df_final.columns
ax = df_final[["id_paciente", 'A_ACT']].groupby('A_ACT').size().plot(kind='bar', color='#367588')
ax.legend(['record count'])
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
df_final['year'] = df_final['fe_resultado'].dt.year
df_final.columns
ax = df_final[["id_paciente", 'year']].groupby('year').size().plot(kind='bar', color='#367558')
ax.legend(['record count'])
ax.set_xlabel('Year')
ax.set_ylabel('Patients')
# Out:
# Text(0, 0.5, 'Patients')

# %%
df_final.head(10)
# Out:
# pregunta  id_paciente                 nombre_encuesta fe_resultado  \
# 0         535255       Prueba de control del Asma ACT 2012-06-29
# 1         535255       Prueba de control del Asma ACT 2012-06-29
# 2         535255       Prueba de control del Asma ACT 2012-06-29
# 3         535255       Prueba de control del Asma ACT 2012-06-29
# 4         535255       Prueba de control del Asma ACT 2012-06-29
# 5         1680091      Prueba de control del Asma ACT 2012-09-27
# 6         1680091      Prueba de control del Asma ACT 2012-09-27
# 7         1680091      Prueba de control del Asma ACT 2012-09-27
# 8         1680091      Prueba de control del Asma ACT 2012-09-27
# 9         1680091      Prueba de control del Asma ACT 2012-09-27
#
# pregunta                           A_ACT                    B_ACT  \
# 0         NaN                             NaN
# 1         NaN                             1 O 2 VECES A LA SEMANA
# 2         DE 2 A 3 NOCHES EN A LA SEMANA  NaN
# 3         NaN                             NaN
# 4         NaN                             NaN
# 5         NaN                             NaN
# 6         NaN                             1 O 2 VECES A LA SEMANA
# 7         UNA O DOS VECES                 NaN
# 8         NaN                             NaN
# 9         NaN                             NaN
#
# pregunta        C_ACT                      D_ACT         FEEDBACK  year
# 0         POCAS VECES  NaN                        NaN              2012
# 1         NaN          NaN                        NaN              2012
# 2         NaN          NaN                        NaN              2012
# 3         NaN          1 VEZ A LA SEMANA O MENOS  NaN              2012
# 4         NaN          NaN                        BIEN CONTROLADA  2012
# 5         POCAS VECES  NaN                        NaN              2012
# 6         NaN          NaN                        NaN              2012
# 7         NaN          NaN                        NaN              2012
# 8         NaN          1 VEZ A LA SEMANA O MENOS  NaN              2012
# 9         NaN          NaN                        BIEN CONTROLADA  2012

# %% [markdown]
# ### Convert each response to categorical data according to each question, respectively.

# %%
df_final.loc[df_final['A_ACT']=='NUNCA', 'A_ACT'] = 1
df_final.loc[df_final['A_ACT']=='UNA VEZ A LA SEMANA', 'A_ACT'] = 2
df_final.loc[df_final['A_ACT']=='UNA O DOS VECES', 'A_ACT'] = 3
df_final.loc[df_final['A_ACT']=='DE 2 A 3 NOCHES EN A LA SEMANA', 'A_ACT'] = 4
df_final.loc[df_final['A_ACT']=='MAS DE 4 NOCHES A LA SEMANA', 'A_ACT'] = 5

df_final.loc[df_final['B_ACT']=='NUNCA', 'B_ACT'] = 1
df_final.loc[df_final['B_ACT']=='1 O 2 VECES A LA SEMANA', 'B_ACT'] = 2 
df_final.loc[df_final['B_ACT']=='DE 3 A 6 VECES A LA SEMANA', 'B_ACT'] = 3
df_final.loc[df_final['B_ACT']=='UNA VEZ AL DIA', 'B_ACT'] = 4
df_final.loc[df_final['B_ACT']=='MAS DE UNA VEZ AL DIA', 'B_ACT'] = 5

df_final.loc[df_final['C_ACT']=='NUNCA', 'C_ACT'] = 1
df_final.loc[df_final['C_ACT']=='POCAS VECES', 'C_ACT'] = 2 
df_final.loc[df_final['C_ACT']=='ALGUNAS VECES', 'C_ACT'] = 3
df_final.loc[df_final['C_ACT']=='CASI SIEMPRE', 'C_ACT'] = 4
df_final.loc[df_final['C_ACT']=='SIEMPRE', 'C_ACT'] = 5

df_final.loc[df_final['D_ACT']=='NUNCA', 'D_ACT'] = 1
df_final.loc[df_final['D_ACT']=='1 VEZ A LA SEMANA O MENOS', 'D_ACT'] = 2 
df_final.loc[df_final['D_ACT']=='2 O 3 VECES A LA SEMANA', 'D_ACT'] = 3
df_final.loc[df_final['D_ACT']=='1 O 2 VECES AL DIA', 'D_ACT'] = 4
df_final.loc[df_final['D_ACT']=='MAS DE 3 VECES AL DIA', 'D_ACT'] = 5

df_final.loc[df_final['FEEDBACK']=='MAL CONTROLADA', 'FEEDBACK'] = 1
df_final.loc[df_final['FEEDBACK']=='NADA CONTROLADA', 'FEEDBACK'] = 2 
df_final.loc[df_final['FEEDBACK']=='ALGO CONTROLADA', 'FEEDBACK'] = 3
df_final.loc[df_final['FEEDBACK']=='BIEN CONTROLADA', 'FEEDBACK'] = 4
df_final.loc[df_final['FEEDBACK']=='TOTALMENTE CONTROLADA', 'FEEDBACK'] = 5

# %%
df_final['A_ACT'] = df_final['A_ACT'].fillna(0)
df_final['B_ACT'] = df_final['B_ACT'].fillna(0)
df_final['C_ACT'] = df_final['C_ACT'].fillna(0)
df_final['D_ACT'] = df_final['D_ACT'].fillna(0)
df_final['FEEDBACK'] = df_final['FEEDBACK'].fillna(0)

# %%
df_final.drop(columns='nombre_encuesta', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-148b4cf02536> in <module>
# ----> 1 df_final.drop(columns='nombre_encuesta', axis = 1, inplace = True)
#       2 df_final
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['nombre_encuesta'] not found in axis"

# %%
df_final
# Out:
# pregunta  id_paciente fe_resultado  A_ACT  B_ACT  C_ACT  D_ACT  FEEDBACK  year
# 0         535255      2012-06-29    0      0      2      0      0         2012
# 1         535255      2012-06-29    0      2      0      0      0         2012
# 2         535255      2012-06-29    4      0      0      0      0         2012
# 3         535255      2012-06-29    0      0      0      2      0         2012
# 4         535255      2012-06-29    0      0      0      4      4         2012
# ...          ...             ...   ..     ..     ..     ..     ..          ...
# 8597      744564      2020-05-20    0      0      2      0      0         2020
# 8598      744564      2020-05-20    0      2      0      0      0         2020
# 8599      744564      2020-05-20    1      0      0      0      0         2020
# 8600      744564      2020-05-20    0      0      0      2      0         2020
# 8601      744564      2020-05-20    0      0      0      4      4         2020
#
# [8575 rows x 8 columns]

# %%
# To watch each category elements, refer to (i.e): df_final['FEEDBACK'].unique()
df_final.groupby('id_paciente').count().shape
# Out:
# (456, 7)

# %% [markdown]
# ### Conclusion
# We see that the ACT test is carried out by means of 4 questions, which are answered by 1715 people and which were registered by date and with their respective results. Same case with feedback question stored as FEEDBACK.
# While the other questions seem to be asked for only one person. Thence, they shall be deleted.
#
# Final procedure. Convert ACT questions to columns as afore shown. In the final dataset `df_final`, we intend to leave the number of rows equivalent to the number of patients.Thus we have obtained a dataframe shaped as 456 patient records x

# %%
df_final.describe(include='all')
# Out:
# pregunta   id_paciente         fe_resultado        A_ACT        B_ACT  \
# count     8.575000e+03  8575                 8575.000000  8575.000000
# unique   NaN            525                 NaN          NaN
# top      NaN            2018-09-20 00:00:00 NaN          NaN
# freq     NaN            325                 NaN          NaN
# first    NaN            2012-06-29 00:00:00 NaN          NaN
# last     NaN            2020-05-29 00:00:00 NaN          NaN
# mean      1.253723e+06  NaN                  0.474519     0.439767
# std       4.158964e+05  NaN                  1.134843     1.052984
# min       5.029890e+05  NaN                  0.000000     0.000000
# 25%       8.979600e+05  NaN                  0.000000     0.000000
# 50%       1.241688e+06  NaN                  0.000000     0.000000
# 75%       1.617372e+06  NaN                  0.000000     0.000000
# max       1.999629e+06  NaN                  5.000000     5.000000
#
# pregunta        C_ACT        D_ACT     FEEDBACK         year
# count     8575.000000  8575.000000  8575.000000  8575.000000
# unique   NaN          NaN          NaN          NaN
# top      NaN          NaN          NaN          NaN
# freq     NaN          NaN          NaN          NaN
# first    NaN          NaN          NaN          NaN
# last     NaN          NaN          NaN          NaN
# mean      0.393819     1.256327     0.749971     2016.713703
# std       0.930716     1.763766     1.565234     1.768374
# min       0.000000     0.000000     0.000000     2012.000000
# 25%       0.000000     0.000000     0.000000     2015.000000
# 50%       0.000000     0.000000     0.000000     2016.000000
# 75%       0.000000     3.000000     0.000000     2018.000000
# max       5.000000     5.000000     5.000000     2020.000000

# %%
df_final.groupby('id_paciente').count().shape
# Out:
# (456, 7)

# %%
msno.matrix(msno.nullity_sort(df_final, sort='descending'))

# %%
df_final.columns
# Out:
# Index(['id_paciente', 'fe_resultado', 'A_ACT', 'B_ACT', 'C_ACT', 'D_ACT',
#        'FEEDBACK', 'year'],
#       dtype='object', name='pregunta')

# %%
df_final.rename(columns={ 'id_paciente':'id_patient',
                            'fe_resultado':'result_date',
                            'A_ACT':'A_ACT',
                            'B_ACT':'B_ACT',
                            'C_ACT':'C_ACT',
                            'D_ACT':'D_ACT',
                            'FEEDBACK':'FEEDBACK',                           
                    },inplace = True)

df_final = df_final.drop(['year'], axis=1)

# %%
df_final.dtypes
# Out:
# pregunta
# id_patient     int64
# result_date    datetime64[ns]
# A_ACT          int64
# B_ACT          int64
# C_ACT          int64
# D_ACT          int64
# FEEDBACK       int64
# dtype: object

# %%
df_final.columns
# Out:
# Index(['id_patient', 'result_date', 'A_ACT', 'B_ACT', 'C_ACT', 'D_ACT',
#        'FEEDBACK'],
#       dtype='object', name='pregunta')

# %%
df_final
# Out:
# pregunta  id_patient result_date  A_ACT  B_ACT  C_ACT  D_ACT  FEEDBACK
# 0         535255     2012-06-29   0      0      2      0      0
# 1         535255     2012-06-29   0      2      0      0      0
# 2         535255     2012-06-29   4      0      0      0      0
# 3         535255     2012-06-29   0      0      0      2      0
# 4         535255     2012-06-29   0      0      0      4      4
# ...          ...            ...  ..     ..     ..     ..     ..
# 8597      744564     2020-05-20   0      0      2      0      0
# 8598      744564     2020-05-20   0      2      0      0      0
# 8599      744564     2020-05-20   1      0      0      0      0
# 8600      744564     2020-05-20   0      0      0      2      0
# 8601      744564     2020-05-20   0      0      0      4      4
#
# [8575 rows x 7 columns]

# %%
df_final = df_final.set_index(df_final.index+1)
df_final.rename_axis(index={'name':'index'})
df_final
# Out:
# pregunta  id_patient result_date  A_ACT  B_ACT  C_ACT  D_ACT  FEEDBACK
# 1         535255     2012-06-29   0      0      2      0      0
# 2         535255     2012-06-29   0      2      0      0      0
# 3         535255     2012-06-29   4      0      0      0      0
# 4         535255     2012-06-29   0      0      0      2      0
# 5         535255     2012-06-29   0      0      0      4      4
# ...          ...            ...  ..     ..     ..     ..     ..
# 8598      744564     2020-05-20   0      0      2      0      0
# 8599      744564     2020-05-20   0      2      0      0      0
# 8600      744564     2020-05-20   1      0      0      0      0
# 8601      744564     2020-05-20   0      0      0      2      0
# 8602      744564     2020-05-20   0      0      0      4      4
#
# [8575 rows x 7 columns]

# %%
df_final.to_csv('./data/cleansed/act_desagregado.csv', sep=',')
